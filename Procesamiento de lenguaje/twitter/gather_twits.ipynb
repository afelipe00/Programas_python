# %%
import tweepy
from random import randint
import json
import time
import csv
import pandas as pd
import os
import sys

# %%
#funciones de busqueda y recoleccion
limit_search = 25
cont_iter = 0
size_search = 420
list_search = []
def pickup_tweets_buffer(tweet):
    global size_search
    global cont_iter
    global limit_search
    if not 'RT @' in tweet.text and len(tweet.text) <= 130:    
        list_search.append(tweet)
        print(f'Busqueda {cont_iter + 1}: tweet {len(list_search)} almacenado')
        if size_search == len(list_search):
            pickup_df(list_search)
            cont_iter+=1
            if cont_iter < limit_search:
                list_search.clear()
                print(f'Busqueda {cont_iter} finalizada\n ')
            else:
                print(f'\nPROCESO DE BUSQUEDA DE TWEET FINALIZADO CON EXITO\n')

def pickup_df(df_tweets):
    ls_dict = list()
    df_final = pd.DataFrame()
    for t in df_tweets:
        dic_tweet = {
        'id': t.id,
        'user': t.user.screen_name,
        'location': t.user.location,
        'tweet': t.text,
        'lang' : t.lang
        }
        ls_dict.append(dic_tweet)
    df_final = pd.DataFrame(ls_dict)
    print(df_final.head(5))
    csv_file(df_final)
    df_final.drop(df_final.index, inplace= True)
def csv_file(df_final):
    df_final.to_csv('tweet.csv',mode= 'a',index= False, header= False)

# %%
class Search_property():
    consumer_key = "x66CyvlFTVxRySc9QG9gXhXbw"
    consumer_secret = "PwPWqXYWHtJocPmprTLwYzdS0BMBLmMKU9DNYUVWvheKI0m7r0"
    access_token = "320544075-GwBCdhpxzInw9wLxVMkIbOEq4FNoGqhfR8Vq0qPl"
    access_token_secret = "5SDDJksgt4TZxb46ybERnGCvgPyXODXgGp4JEaiB5WtGd"

    def __init__(self):   
        self.lenguajes = ['en', 'es']
        self.track = ['Coronavirus', 'coronavirus', 'covid-19', 'COVID-19', "SARS-CoV-2", "covid 19", "quarantine", "pandemia", "cuarentena", "COVID19", "covid19"]
        self.c_key = self.consumer_key
        self.c_secret = self.consumer_secret
        self.a_token = self.access_token
        self.a_secret = self.access_token_secret

class Stream_Tweetslistener(tweepy.StreamListener):
    #se incia la coneccion
    def on_connect(self):
        print("Coneccion iniciada")
        return super().on_connect()
    #aca es donde se debe realizar la recoleccion de los datos
    def on_status(self, status):
        tweet = status
        pickup_tweets_buffer(tweet)
        global cont_iter
        global limit_search
        if cont_iter == limit_search:
            print('coneccion finalizada')
            streaming_api.disconnect()
    def on_error(self, status_code):
        print('Error: ', status_code)

# %%
sp = Search_property()
auth = tweepy.OAuthHandler(sp.c_key,sp.c_secret)
auth.set_access_token(sp.a_token,sp.a_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
if __name__ == "__main__": 
    stream = Stream_Tweetslistener()
    streaming_api = tweepy.Stream(auth=api.auth, listener=stream, tweet_mode='extended')
    streaming_api.filter(languages= sp.lenguajes, track= sp.track, locations= [-10.6,34.4,74.7,57.0,-125.2,25.0,-67.3,48.7], stall_warnings=True)
# Out:
# o
# Busqueda 24: tweet 296 almacenado
# Busqueda 24: tweet 297 almacenado
# Busqueda 24: tweet 298 almacenado
# Busqueda 24: tweet 299 almacenado
# Busqueda 24: tweet 300 almacenado
# Busqueda 24: tweet 301 almacenado
# Busqueda 24: tweet 302 almacenado
# Busqueda 24: tweet 303 almacenado
# Busqueda 24: tweet 304 almacenado
# Busqueda 24: tweet 305 almacenado
# Busqueda 24: tweet 306 almacenado
# Busqueda 24: tweet 307 almacenado
# Busqueda 24: tweet 308 almacenado
# Busqueda 24: tweet 309 almacenado
# Busqueda 24: tweet 310 almacenado
# Busqueda 24: tweet 311 almacenado
# Busqueda 24: tweet 312 almacenado
# Busqueda 24: tweet 313 almacenado
# Busqueda 24: tweet 314 almacenado
# Busqueda 24: tweet 315 almacenado
# Busqueda 24: tweet 316 almacenado
# Busqueda 24: tweet 317 almacenado
# Busqueda 24: tweet 318 almacenado
# Busqueda 24: tweet 319 almacenado
# Busqueda 24: tweet 320 almacenado
# Busqueda 24: tweet 321 almacenado
# Busqueda 24: tweet 322 almacenado
# Busqueda 24: tweet 323 almacenado
# Busqueda 24: tweet 324 almacenado
# Busqueda 24: tweet 325 almacenado
# Busqueda 24: tweet 326 almacenado
# Busqueda 24: tweet 327 almacenado
# Busqueda 24: tweet 328 almacenado
# Busqueda 24: tweet 329 almacenado
# Busqueda 24: tweet 330 almacenado
# Busqueda 24: tweet 331 almacenado
# Busqueda 24: tweet 332 almacenado
# Busqueda 24: tweet 333 almacenado
# Busqueda 24: tweet 334 almacenado
# Busqueda 24: tweet 335 almacenado
# Busqueda 24: tweet 336 almacenado
# Busqueda 24: tweet 337 almacenado
# Busqueda 24: tweet 338 almacenado
# Busqueda 24: tweet 339 almacenado
# Busqueda 24: tweet 340 almacenado
# Busqueda 24: tweet 341 almacenado
# Busqueda 24: tweet 342 almacenado
# Busqueda 24: tweet 343 almacenado
# Busqueda 24: tweet 344 almacenado
# Busqueda 24: tweet 345 almacenado
# Busqueda 24: tweet 346 almacenado
# Busqueda 24: tweet 347 almacenado
# Busqueda 24: tweet 348 almacenado
# Busqueda 24: tweet 349 almacenado
# Busqueda 24: tweet 350 almacenado
# Busqueda 24: tweet 351 almacenado
# Busqueda 24: tweet 352 almacenado
# Busqueda 24: tweet 353 almacenado
# Busqueda 24: tweet 354 almacenado
# Busqueda 24: tweet 355 almacenado
# Busqueda 24: tweet 356 almacenado
# Busqueda 24: tweet 357 almacenado
# Busqueda 24: tweet 358 almacenado
# Busqueda 24: tweet 359 almacenado
# Busqueda 24: tweet 360 almacenado
# Busqueda 24: tweet 361 almacenado
# Busqueda 24: tweet 362 almacenado
# Busqueda 24: tweet 363 almacenado
# Busqueda 24: tweet 364 almacenado
# Busqueda 24: tweet 365 almacenado
# Busqueda 24: tweet 366 almacenado
# Busqueda 24: tweet 367 almacenado
# Busqueda 24: tweet 368 almacenado
# Busqueda 24: tweet 369 almacenado
# Busqueda 24: tweet 370 almacenado
# Busqueda 24: tweet 371 almacenado
# Busqueda 24: tweet 372 almacenado
# Busqueda 24: tweet 373 almacenado
# Busqueda 24: tweet 374 almacenado
# Busqueda 24: tweet 375 almacenado
# Busqueda 24: tweet 376 almacenado
# Busqueda 24: tweet 377 almacenado
# Busqueda 24: tweet 378 almacenado
# Busqueda 24: tweet 379 almacenado
# Busqueda 24: tweet 380 almacenado
# Busqueda 24: tweet 381 almacenado
# Busqueda 24: tweet 382 almacenado
# Busqueda 24: tweet 383 almacenado
# Busqueda 24: tweet 384 almacenado
# Busqueda 24: tweet 385 almacenado
# Busqueda 24: tweet 386 almacenado
# Busqueda 24: tweet 387 almacenado
# Busqueda 24: tweet 388 almacenado
# Busqueda 24: tweet 389 almacenado
# Busqueda 24: tweet 390 almacenado
# Busqueda 24: tweet 391 almacenado
# Busqueda 24: tweet 392 almacenado
# Busqueda 24: tweet 393 almacenado
# Busqueda 24: tweet 394 almacenado
# Busqueda 24: tweet 395 almacenado
# Busqueda 24: tweet 396 almacenado
# Busqueda 24: tweet 397 almacenado
# Busqueda 24: tweet 398 almacenado
# Busqueda 24: tweet 399 almacenado
# Busqueda 24: tweet 400 almacenado
# Busqueda 24: tweet 401 almacenado
# Busqueda 24: tweet 402 almacenado
# Busqueda 24: tweet 403 almacenado
# Busqueda 24: tweet 404 almacenado
# Busqueda 24: tweet 405 almacenado
# Busqueda 24: tweet 406 almacenado
# Busqueda 24: tweet 407 almacenado
# Busqueda 24: tweet 408 almacenado
# Busqueda 24: tweet 409 almacenado
# Busqueda 24: tweet 410 almacenado
# Busqueda 24: tweet 411 almacenado
# Busqueda 24: tweet 412 almacenado
# Busqueda 24: tweet 413 almacenado
# Busqueda 24: tweet 414 almacenado
# Busqueda 24: tweet 415 almacenado
# Busqueda 24: tweet 416 almacenado
# Busqueda 24: tweet 417 almacenado
# Busqueda 24: tweet 418 almacenado
# Busqueda 24: tweet 419 almacenado
# Busqueda 24: tweet 420 almacenado
#                     id            user         location  \
# 0  1251204713917427713      BDmusician       Boston, MA
# 1  1251204713791488002      Doctor_Vic             None
# 2  1251204713871106048  nicolemxchelle       Tacoma, WA
# 3  1251204713833472004      TvlEcuador  Quito - Ecuador
# 4  1251204713971716096       greeenorg             None
#
#                                                tweet lang
# 0  This quarantine has allowed me to get back int...   en
# 1            And he is also not very good at numbers   en
# 2                   i never had any to start with so   en
# 3  #Infórmate ➡️ La ministra @mariapaularomo info...   es
# 4  Coronavirus: Latin America's biggest graveyard...   en
# Busqueda 24 finalizada
#
# Busqueda 25: tweet 1 almacenado
# Busqueda 25: tweet 2 almacenado
# Busqueda 25: tweet 3 almacenado
# Busqueda 25: tweet 4 almacenado
# Busqueda 25: tweet 5 almacenado
# Busqueda 25: tweet 6 almacenado
# Busqueda 25: tweet 7 almacenado
# Busqueda 25: tweet 8 almacenado
# Busqueda 25: tweet 9 almacenado
# Busqueda 25: tweet 10 almacenado
# Busqueda 25: tweet 11 almacenado
# Busqueda 25: tweet 12 almacenado
# Busqueda 25: tweet 13 almacenado
# Busqueda 25: tweet 14 almacenado
# Busqueda 25: tweet 15 almacenado
# Busqueda 25: tweet 16 almacenado
# Busqueda 25: tweet 17 almacenado
# Busqueda 25: tweet 18 almacenado
# Busqueda 25: tweet 19 almacenado
# Busqueda 25: tweet 20 almacenado
# Busqueda 25: tweet 21 almacenado
# Busqueda 25: tweet 22 almacenado
# Busqueda 25: tweet 23 almacenado
# Busqueda 25: tweet 24 almacenado
# Busqueda 25: tweet 25 almacenado
# Busqueda 25: tweet 26 almacenado
# Busqueda 25: tweet 27 almacenado
# Busqueda 25: tweet 28 almacenado
# Busqueda 25: tweet 29 almacenado
# Busqueda 25: tweet 30 almacenado
# Busqueda 25: tweet 31 almacenado
# Busqueda 25: tweet 32 almacenado
# Busqueda 25: tweet 33 almacenado
# Busqueda 25: tweet 34 almacenado
# Busqueda 25: tweet 35 almacenado
# Busqueda 25: tweet 36 almacenado
# Busqueda 25: tweet 37 almacenado
# Busqueda 25: tweet 38 almacenado
# Busqueda 25: tweet 39 almacenado
# Busqueda 25: tweet 40 almacenado
# Busqueda 25: tweet 41 almacenado
# Busqueda 25: tweet 42 almacenado
# Busqueda 25: tweet 43 almacenado
# Busqueda 25: tweet 44 almacenado
# Busqueda 25: tweet 45 almacenado
# Busqueda 25: tweet 46 almacenado
# Busqueda 25: tweet 47 almacenado
# Busqueda 25: tweet 48 almacenado
# Busqueda 25: tweet 49 almacenado
# Busqueda 25: tweet 50 almacenado
# Busqueda 25: tweet 51 almacenado
# Busqueda 25: tweet 52 almacenado
# Busqueda 25: tweet 53 almacenado
# Busqueda 25: tweet 54 almacenado
# Busqueda 25: tweet 55 almacenado
# Busqueda 25: tweet 56 almacenado
# Busqueda 25: tweet 57 almacenado
# Busqueda 25: tweet 58 almacenado
# Busqueda 25: tweet 59 almacenado
# Busqueda 25: tweet 60 almacenado
# Busqueda 25: tweet 61 almacenado
# Busqueda 25: tweet 62 almacenado
# Busqueda 25: tweet 63 almacenado
# Busqueda 25: tweet 64 almacenado
# Busqueda 25: tweet 65 almacenado
# Busqueda 25: tweet 66 almacenado
# Busqueda 25: tweet 67 almacenado
# Busqueda 25: tweet 68 almacenado
# Busqueda 25: tweet 69 almacenado
# Busqueda 25: tweet 70 almacenado
# Busqueda 25: tweet 71 almacenado
# Busqueda 25: tweet 72 almacenado
# Busqueda 25: tweet 73 almacenado
# Busqueda 25: tweet 74 almacenado
# Busqueda 25: tweet 75 almacenado
# Busqueda 25: tweet 76 almacenado
# Busqueda 25: tweet 77 almacenado
# Busqueda 25: tweet 78 almacenado
# Busqueda 25: tweet 79 almacenado
# Busqueda 25: tweet 80 almacenado
# Busqueda 25: tweet 81 almacenado
# Busqueda 25: tweet 82 almacenado
# Busqueda 25: tweet 83 almacenado
# Busqueda 25: tweet 84 almacenado
# Busqueda 25: tweet 85 almacenado
# Busqueda 25: tweet 86 almacenado
# Busqueda 25: tweet 87 almacenado
# Busqueda 25: tweet 88 almacenado
# Busqueda 25: tweet 89 almacenado
# Busqueda 25: tweet 90 almacenado
# Busqueda 25: tweet 91 almacenado
# Busqueda 25: tweet 92 almacenado
# Busqueda 25: tweet 93 almacenado
# Busqueda 25: tweet 94 almacenado
# Busqueda 25: tweet 95 almacenado
# Busqueda 25: tweet 96 almacenado
# Busqueda 25: tweet 97 almacenado
# Busqueda 25: tweet 98 almacenado
# Busqueda 25: tweet 99 almacenado
# Busqueda 25: tweet 100 almacenado
# Busqueda 25: tweet 101 almacenado
# Busqueda 25: tweet 102 almacenado
# Busqueda 25: tweet 103 almacenado
# Busqueda 25: tweet 104 almacenado
# Busqueda 25: tweet 105 almacenado
# Busqueda 25: tweet 106 almacenado
# Busqueda 25: tweet 107 almacenado
# Busqueda 25: tweet 108 almacenado
# Busqueda 25: tweet 109 almacenado
# Busqueda 25: tweet 110 almacenado
# Busqueda 25: tweet 111 almacenado
# Busqueda 25: tweet 112 almacenado
# Busqueda 25: tweet 113 almacenado
# Busqueda 25: tweet 114 almacenado
# Busqueda 25: tweet 115 almacenado
# Busqueda 25: tweet 116 almacenado
# Busqueda 25: tweet 117 almacenado
# Busqueda 25: tweet 118 almacenado
# Busqueda 25: tweet 119 almacenado
# Busqueda 25: tweet 120 almacenado
# Busqueda 25: tweet 121 almacenado
# Busqueda 25: tweet 122 almacenado
# Busqueda 25: tweet 123 almacenado
# Busqueda 25: tweet 124 almacenado
# Busqueda 25: tweet 125 almacenado
# Busqueda 25: tweet 126 almacenado
# Busqueda 25: tweet 127 almacenado
# Busqueda 25: tweet 128 almacenado
# Busqueda 25: tweet 129 almacenado
# Busqueda 25: tweet 130 almacenado
# Busqueda 25: tweet 131 almacenado
# Busqueda 25: tweet 132 almacenado
# Busqueda 25: tweet 133 almacenado
# Busqueda 25: tweet 134 almacenado
# Busqueda 25: tweet 135 almacenado
# Busqueda 25: tweet 136 almacenado
# Busqueda 25: tweet 137 almacenado
# Busqueda 25: tweet 138 almacenado
# Busqueda 25: tweet 139 almacenado
# Busqueda 25: tweet 140 almacenado
# Busqueda 25: tweet 141 almacenado
# Busqueda 25: tweet 142 almacenado
# Busqueda 25: tweet 143 almacenado
# Busqueda 25: tweet 144 almacenado
# Busqueda 25: tweet 145 almacenado
# Busqueda 25: tweet 146 almacenado
# Busqueda 25: tweet 147 almacenado
# Busqueda 25: tweet 148 almacenado
# Busqueda 25: tweet 149 almacenado
# Busqueda 25: tweet 150 almacenado
# Busqueda 25: tweet 151 almacenado
# Busqueda 25: tweet 152 almacenado
# Busqueda 25: tweet 153 almacenado
# Busqueda 25: tweet 154 almacenado
# Busqueda 25: tweet 155 almacenado
# Busqueda 25: tweet 156 almacenado
# Busqueda 25: tweet 157 almacenado
# Busqueda 25: tweet 158 almacenado
# Busqueda 25: tweet 159 almacenado
# Busqueda 25: tweet 160 almacenado
# Busqueda 25: tweet 161 almacenado
# Busqueda 25: tweet 162 almacenado
# Busqueda 25: tweet 163 almacenado
# Busqueda 25: tweet 164 almacenado
# Busqueda 25: tweet 165 almacenado
# Busqueda 25: tweet 166 almacenado
# Busqueda 25: tweet 167 almacenado
# Busqueda 25: tweet 168 almacenado
# Busqueda 25: tweet 169 almacenado
# Busqueda 25: tweet 170 almacenado
# Busqueda 25: tweet 171 almacenado
# Busqueda 25: tweet 172 almacenado
# Busqueda 25: tweet 173 almacenado
# Busqueda 25: tweet 174 almacenado
# Busqueda 25: tweet 175 almacenado
# Busqueda 25: tweet 176 almacenado
# Busqueda 25: tweet 177 almacenado
# Busqueda 25: tweet 178 almacenado
# Busqueda 25: tweet 179 almacenado
# Busqueda 25: tweet 180 almacenado
# Busqueda 25: tweet 181 almacenado
# Busqueda 25: tweet 182 almacenado
# Busqueda 25: tweet 183 almacenado
# Busqueda 25: tweet 184 almacenado
# Busqueda 25: tweet 185 almacenado
# Busqueda 25: tweet 186 almacenado
# Busqueda 25: tweet 187 almacenado
# Busqueda 25: tweet 188 almacenado
# Busqueda 25: tweet 189 almacenado
# Busqueda 25: tweet 190 almacenado
# Busqueda 25: tweet 191 almacenado
# Busqueda 25: tweet 192 almacenado
# Busqueda 25: tweet 193 almacenado
# Busqueda 25: tweet 194 almacenado
# Busqueda 25: tweet 195 almacenado
# Busqueda 25: tweet 196 almacenado
# Busqueda 25: tweet 197 almacenado
# Busqueda 25: tweet 198 almacenado
# Busqueda 25: tweet 199 almacenado
# Busqueda 25: tweet 200 almacenado
# Busqueda 25: tweet 201 almacenado
# Busqueda 25: tweet 202 almacenado
# Busqueda 25: tweet 203 almacenado
# Busqueda 25: tweet 204 almacenado
# Busqueda 25: tweet 205 almacenado
# Busqueda 25: tweet 206 almacenado
# Busqueda 25: tweet 207 almacenado
# Busqueda 25: tweet 208 almacenado
# Busqueda 25: tweet 209 almacenado
# Busqueda 25: tweet 210 almacenado
# Busqueda 25: tweet 211 almacenado
# Busqueda 25: tweet 212 almacenado
# Busqueda 25: tweet 213 almacenado
# Busqueda 25: tweet 214 almacenado
# Busqueda 25: tweet 215 almacenado
# Busqueda 25: tweet 216 almacenado
# Busqueda 25: tweet 217 almacenado
# Busqueda 25: tweet 218 almacenado
# Busqueda 25: tweet 219 almacenado
# Busqueda 25: tweet 220 almacenado
# Busqueda 25: tweet 221 almacenado
# Busqueda 25: tweet 222 almacenado
# Busqueda 25: tweet 223 almacenado
# Busqueda 25: tweet 224 almacenado
# Busqueda 25: tweet 225 almacenado
# Busqueda 25: tweet 226 almacenado
# Busqueda 25: tweet 227 almacenado
# Busqueda 25: tweet 228 almacenado
# Busqueda 25: tweet 229 almacenado
# Busqueda 25: tweet 230 almacenado
# Busqueda 25: tweet 231 almacenado
# Busqueda 25: tweet 232 almacenado
# Busqueda 25: tweet 233 almacenado
# Busqueda 25: tweet 234 almacenado
# Busqueda 25: tweet 235 almacenado
# Busqueda 25: tweet 236 almacenado
# Busqueda 25: tweet 237 almacenado
# Busqueda 25: tweet 238 almacenado
# Busqueda 25: tweet 239 almacenado
# Busqueda 25: tweet 240 almacenado
# Busqueda 25: tweet 241 almacenado
# Busqueda 25: tweet 242 almacenado
# Busqueda 25: tweet 243 almacenado
# Busqueda 25: tweet 244 almacenado
# Busqueda 25: tweet 245 almacenado
# Busqueda 25: tweet 246 almacenado
# Busqueda 25: tweet 247 almacenado
# Busqueda 25: tweet 248 almacenado
# Busqueda 25: tweet 249 almacenado
# Busqueda 25: tweet 250 almacenado
# Busqueda 25: tweet 251 almacenado
# Busqueda 25: tweet 252 almacenado
# Busqueda 25: tweet 253 almacenado
# Busqueda 25: tweet 254 almacenado
# Busqueda 25: tweet 255 almacenado
# Busqueda 25: tweet 256 almacenado
# Busqueda 25: tweet 257 almacenado
# Busqueda 25: tweet 258 almacenado
# Busqueda 25: tweet 259 almacenado
# Busqueda 25: tweet 260 almacenado
# Busqueda 25: tweet 261 almacenado
# Busqueda 25: tweet 262 almacenado
# Busqueda 25: tweet 263 almacenado
# Busqueda 25: tweet 264 almacenado
# Busqueda 25: tweet 265 almacenado
# Busqueda 25: tweet 266 almacenado
# Busqueda 25: tweet 267 almacenado
# Busqueda 25: tweet 268 almacenado
# Busqueda 25: tweet 269 almacenado
# Busqueda 25: tweet 270 almacenado
# Busqueda 25: tweet 271 almacenado
# Busqueda 25: tweet 272 almacenado
# Busqueda 25: tweet 273 almacenado
# Busqueda 25: tweet 274 almacenado
# Busqueda 25: tweet 275 almacenado
# Busqueda 25: tweet 276 almacenado
# Busqueda 25: tweet 277 almacenado
# Busqueda 25: tweet 278 almacenado
# Busqueda 25: tweet 279 almacenado
# Busqueda 25: tweet 280 almacenado
# Busqueda 25: tweet 281 almacenado
# Busqueda 25: tweet 282 almacenado
# Busqueda 25: tweet 283 almacenado
# Busqueda 25: tweet 284 almacenado
# Busqueda 25: tweet 285 almacenado
# Busqueda 25: tweet 286 almacenado
# Busqueda 25: tweet 287 almacenado
# Busqueda 25: tweet 288 almacenado
# Busqueda 25: tweet 289 almacenado
# Busqueda 25: tweet 290 almacenado
# Busqueda 25: tweet 291 almacenado
# Busqueda 25: tweet 292 almacenado
# Busqueda 25: tweet 293 almacenado
# Busqueda 25: tweet 294 almacenado
# Busqueda 25: tweet 295 almacenado
# Busqueda 25: tweet 296 almacenado
# Busqueda 25: tweet 297 almacenado
# Busqueda 25: tweet 298 almacenado
# Busqueda 25: tweet 299 almacenado
# Busqueda 25: tweet 300 almacenado
# Busqueda 25: tweet 301 almacenado
# Busqueda 25: tweet 302 almacenado
# Busqueda 25: tweet 303 almacenado
# Busqueda 25: tweet 304 almacenado
# Busqueda 25: tweet 305 almacenado
# Busqueda 25: tweet 306 almacenado
# Busqueda 25: tweet 307 almacenado
# Busqueda 25: tweet 308 almacenado
# Busqueda 25: tweet 309 almacenado
# Busqueda 25: tweet 310 almacenado
# Busqueda 25: tweet 311 almacenado
# Busqueda 25: tweet 312 almacenado
# Busqueda 25: tweet 313 almacenado
# Busqueda 25: tweet 314 almacenado
# Busqueda 25: tweet 315 almacenado
# Busqueda 25: tweet 316 almacenado
# Busqueda 25: tweet 317 almacenado
# Busqueda 25: tweet 318 almacenado
# Busqueda 25: tweet 319 almacenado
# Busqueda 25: tweet 320 almacenado
# Busqueda 25: tweet 321 almacenado
# Busqueda 25: tweet 322 almacenado
# Busqueda 25: tweet 323 almacenado
# Busqueda 25: tweet 324 almacenado
# Busqueda 25: tweet 325 almacenado
# Busqueda 25: tweet 326 almacenado
# Busqueda 25: tweet 327 almacenado
# Busqueda 25: tweet 328 almacenado
# Busqueda 25: tweet 329 almacenado
# Busqueda 25: tweet 330 almacenado
# Busqueda 25: tweet 331 almacenado
# Busqueda 25: tweet 332 almacenado
# Busqueda 25: tweet 333 almacenado
# Busqueda 25: tweet 334 almacenado
# Busqueda 25: tweet 335 almacenado
# Busqueda 25: tweet 336 almacenado
# Busqueda 25: tweet 337 almacenado
# Busqueda 25: tweet 338 almacenado
# Busqueda 25: tweet 339 almacenado
# Busqueda 25: tweet 340 almacenado
# Busqueda 25: tweet 341 almacenado
# Busqueda 25: tweet 342 almacenado
# Busqueda 25: tweet 343 almacenado
# Busqueda 25: tweet 344 almacenado
# Busqueda 25: tweet 345 almacenado
# Busqueda 25: tweet 346 almacenado
# Busqueda 25: tweet 347 almacenado
# Busqueda 25: tweet 348 almacenado
# Busqueda 25: tweet 349 almacenado
# Busqueda 25: tweet 350 almacenado
# Busqueda 25: tweet 351 almacenado
# Busqueda 25: tweet 352 almacenado
# Busqueda 25: tweet 353 almacenado
# Busqueda 25: tweet 354 almacenado
# Busqueda 25: tweet 355 almacenado
# Busqueda 25: tweet 356 almacenado
# Busqueda 25: tweet 357 almacenado
# Busqueda 25: tweet 358 almacenado
# Busqueda 25: tweet 359 almacenado
# Busqueda 25: tweet 360 almacenado
# Busqueda 25: tweet 361 almacenado
# Busqueda 25: tweet 362 almacenado
# Busqueda 25: tweet 363 almacenado
# Busqueda 25: tweet 364 almacenado
# Busqueda 25: tweet 365 almacenado
# Busqueda 25: tweet 366 almacenado
# Busqueda 25: tweet 367 almacenado
# Busqueda 25: tweet 368 almacenado
# Busqueda 25: tweet 369 almacenado
# Busqueda 25: tweet 370 almacenado
# Busqueda 25: tweet 371 almacenado
# Busqueda 25: tweet 372 almacenado
# Busqueda 25: tweet 373 almacenado
# Busqueda 25: tweet 374 almacenado
# Busqueda 25: tweet 375 almacenado
# Busqueda 25: tweet 376 almacenado
# Busqueda 25: tweet 377 almacenado
# Busqueda 25: tweet 378 almacenado
# Busqueda 25: tweet 379 almacenado
# Busqueda 25: tweet 380 almacenado
# Busqueda 25: tweet 381 almacenado
# Busqueda 25: tweet 382 almacenado
# Busqueda 25: tweet 383 almacenado
# Busqueda 25: tweet 384 almacenado
# Busqueda 25: tweet 385 almacenado
# Busqueda 25: tweet 386 almacenado
# Busqueda 25: tweet 387 almacenado
# Busqueda 25: tweet 388 almacenado
# Busqueda 25: tweet 389 almacenado
# Busqueda 25: tweet 390 almacenado
# Busqueda 25: tweet 391 almacenado
# Busqueda 25: tweet 392 almacenado
# Busqueda 25: tweet 393 almacenado
# Busqueda 25: tweet 394 almacenado
# Busqueda 25: tweet 395 almacenado
# Busqueda 25: tweet 396 almacenado
# Busqueda 25: tweet 397 almacenado
# Busqueda 25: tweet 398 almacenado
# Busqueda 25: tweet 399 almacenado
# Busqueda 25: tweet 400 almacenado
# Busqueda 25: tweet 401 almacenado
# Busqueda 25: tweet 402 almacenado
# Busqueda 25: tweet 403 almacenado
# Busqueda 25: tweet 404 almacenado
# Busqueda 25: tweet 405 almacenado
# Busqueda 25: tweet 406 almacenado
# Busqueda 25: tweet 407 almacenado
# Busqueda 25: tweet 408 almacenado
# Busqueda 25: tweet 409 almacenado
# Busqueda 25: tweet 410 almacenado
# Busqueda 25: tweet 411 almacenado
# Busqueda 25: tweet 412 almacenado
# Busqueda 25: tweet 413 almacenado
# Busqueda 25: tweet 414 almacenado
# Busqueda 25: tweet 415 almacenado
# Busqueda 25: tweet 416 almacenado
# Busqueda 25: tweet 417 almacenado
# Busqueda 25: tweet 418 almacenado
# Busqueda 25: tweet 419 almacenado
# Busqueda 25: tweet 420 almacenado
#                     id            user                 location  \
# 0  1251204878065717255      cmdrbob558  Ottawa, Ontario, Canada
# 1  1251204878057254918    HectorMoreta            Santo Domingo
# 2  1251204878115930112    13yearsoftay                     None
# 3  1251204878338347011    cornichecorp              Cyberspace
# 4  1251204881668616192  jordan_gethers          Tallahassee, FL
#
#                                                tweet lang
# 0  Get ready for a virtual Canada Day party this ...   en
# 1      Ese señor minimo es el coronavirus en persona   es
# 2  This may suck right now but she is handling th...   en
# 3  Police in China are Using AI Helmets to Screen...   en
# 4             May be "corny" but yes sirr corn me up   en
#
# PROCESO DE BUSQUEDA DE TWEET FINALIZADO CON EXITO
#
# coneccion finalizada
