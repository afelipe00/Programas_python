# %%
import tweepy
from random import randint
import json
import time
import csv
import pandas as pd
import os
import sys

# %%
#funciones de busqueda y recoleccion
limit_search = 50
cont_iter = 0
size_search = 420
list_search = []
def pickup_tweets_buffer(tweet):
    global size_search
    global cont_iter
    global limit_search
    if not 'RT @' in tweet.text and len(tweet.text) <= 130:    
        list_search.append(tweet)
        print(f'Busqueda {cont_iter + 1}: tweet {len(list_search)} almacenado')
        if size_search == len(list_search):
            pickup_df(list_search)
            cont_iter+=1
            if cont_iter < limit_search:
                list_search.clear()
                print(f'Busqueda {cont_iter} finalizada\n ')
            else:
                print(f'\nPROCESO DE BUSQUEDA DE TWEET FINALIZADO CON EXITO\n')

def pickup_df(df_tweets):
    ls_dict = list()
    df_final = pd.DataFrame()
    for t in df_tweets:
        dic_tweet = {
        'id': t.id,
        'user': t.user.screen_name,
        'location': t.user.location,
        'tweet': t.text,
        'lang' : t.lang
        }
        ls_dict.append(dic_tweet)
    df_final = pd.DataFrame(ls_dict)
    print(df_final.head(5))
    csv_file(df_final)
    df_final.drop(df_final.index, inplace= True)
def csv_file(df_final):
    df_final.to_csv('tweet.csv',mode= 'a',index= False, header= False)

# %%
class Search_property():
    consumer_key = "x66CyvlFTVxRySc9QG9gXhXbw"
    consumer_secret = "PwPWqXYWHtJocPmprTLwYzdS0BMBLmMKU9DNYUVWvheKI0m7r0"
    access_token = "320544075-GwBCdhpxzInw9wLxVMkIbOEq4FNoGqhfR8Vq0qPl"
    access_token_secret = "5SDDJksgt4TZxb46ybERnGCvgPyXODXgGp4JEaiB5WtGd"

    def __init__(self):   
        self.lenguajes = ['en', 'es']
        self.track = ['Coronavirus', 'coronavirus', 'covid-19', 'COVID-19', "SARS-CoV-2", "covid 19", "quarantine", "pandemia", "cuarentena", "COVID19", "covid19"]
        self.c_key = self.consumer_key
        self.c_secret = self.consumer_secret
        self.a_token = self.access_token
        self.a_secret = self.access_token_secret

class Stream_Tweetslistener(tweepy.StreamListener):
    #se incia la coneccion
    def on_connect(self):
        print("Coneccion iniciada")
        return super().on_connect()
    #aca es donde se debe realizar la recoleccion de los datos
    def on_status(self, status):
        tweet = status
        pickup_tweets_buffer(tweet)
        global cont_iter
        global limit_search
        if cont_iter == limit_search:
            print('coneccion finalizada')
            streaming_api.disconnect()
    def on_error(self, status_code):
        print('Error: ', status_code)

# %%
sp = Search_property()
auth = tweepy.OAuthHandler(sp.c_key,sp.c_secret)
auth.set_access_token(sp.a_token,sp.a_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
if __name__ == "__main__": 
    stream = Stream_Tweetslistener()
    streaming_api = tweepy.Stream(auth=api.auth, listener=stream, tweet_mode='extended')
    streaming_api.filter(languages= sp.lenguajes, track= sp.track, locations= [-10.6,34.4,74.7,57.0,-125.2,25.0,-67.3,48.7], stall_warnings=True)
# Out:
# do
# Busqueda 37: tweet 81 almacenado
# Busqueda 37: tweet 82 almacenado
# Busqueda 37: tweet 83 almacenado
# Busqueda 37: tweet 84 almacenado
# Busqueda 37: tweet 85 almacenado
# Busqueda 37: tweet 86 almacenado
# Busqueda 37: tweet 87 almacenado
# Busqueda 37: tweet 88 almacenado
# Busqueda 37: tweet 89 almacenado
# Busqueda 37: tweet 90 almacenado
# Busqueda 37: tweet 91 almacenado
# Busqueda 37: tweet 92 almacenado
# Busqueda 37: tweet 93 almacenado
# Busqueda 37: tweet 94 almacenado
# Busqueda 37: tweet 95 almacenado
# Busqueda 37: tweet 96 almacenado
# Busqueda 37: tweet 97 almacenado
# Busqueda 37: tweet 98 almacenado
# Busqueda 37: tweet 99 almacenado
# Busqueda 37: tweet 100 almacenado
# Busqueda 37: tweet 101 almacenado
# Busqueda 37: tweet 102 almacenado
# Busqueda 37: tweet 103 almacenado
# Busqueda 37: tweet 104 almacenado
# Busqueda 37: tweet 105 almacenado
# Busqueda 37: tweet 106 almacenado
# Busqueda 37: tweet 107 almacenado
# Busqueda 37: tweet 108 almacenado
# Busqueda 37: tweet 109 almacenado
# Busqueda 37: tweet 110 almacenado
# Busqueda 37: tweet 111 almacenado
# Busqueda 37: tweet 112 almacenado
# Busqueda 37: tweet 113 almacenado
# Busqueda 37: tweet 114 almacenado
# Busqueda 37: tweet 115 almacenado
# Busqueda 37: tweet 116 almacenado
# Busqueda 37: tweet 117 almacenado
# Busqueda 37: tweet 118 almacenado
# Busqueda 37: tweet 119 almacenado
# Busqueda 37: tweet 120 almacenado
# Busqueda 37: tweet 121 almacenado
# Busqueda 37: tweet 122 almacenado
# Busqueda 37: tweet 123 almacenado
# Busqueda 37: tweet 124 almacenado
# Busqueda 37: tweet 125 almacenado
# Busqueda 37: tweet 126 almacenado
# Busqueda 37: tweet 127 almacenado
# Busqueda 37: tweet 128 almacenado
# Busqueda 37: tweet 129 almacenado
# Busqueda 37: tweet 130 almacenado
# Busqueda 37: tweet 131 almacenado
# Busqueda 37: tweet 132 almacenado
# Busqueda 37: tweet 133 almacenado
# Busqueda 37: tweet 134 almacenado
# Busqueda 37: tweet 135 almacenado
# Busqueda 37: tweet 136 almacenado
# Busqueda 37: tweet 137 almacenado
# Busqueda 37: tweet 138 almacenado
# Busqueda 37: tweet 139 almacenado
# Busqueda 37: tweet 140 almacenado
# Busqueda 37: tweet 141 almacenado
# Busqueda 37: tweet 142 almacenado
# Busqueda 37: tweet 143 almacenado
# Busqueda 37: tweet 144 almacenado
# Busqueda 37: tweet 145 almacenado
# Busqueda 37: tweet 146 almacenado
# Busqueda 37: tweet 147 almacenado
# Busqueda 37: tweet 148 almacenado
# Busqueda 37: tweet 149 almacenado
# Busqueda 37: tweet 150 almacenado
# Busqueda 37: tweet 151 almacenado
# Busqueda 37: tweet 152 almacenado
# Busqueda 37: tweet 153 almacenado
# Busqueda 37: tweet 154 almacenado
# Busqueda 37: tweet 155 almacenado
# Busqueda 37: tweet 156 almacenado
# Busqueda 37: tweet 157 almacenado
# Busqueda 37: tweet 158 almacenado
# Busqueda 37: tweet 159 almacenado
# Busqueda 37: tweet 160 almacenado
# Busqueda 37: tweet 161 almacenado
# Busqueda 37: tweet 162 almacenado
# Busqueda 37: tweet 163 almacenado
# Busqueda 37: tweet 164 almacenado
# Busqueda 37: tweet 165 almacenado
# Busqueda 37: tweet 166 almacenado
# Busqueda 37: tweet 167 almacenado
# Busqueda 37: tweet 168 almacenado
# Busqueda 37: tweet 169 almacenado
# Busqueda 37: tweet 170 almacenado
# Busqueda 37: tweet 171 almacenado
# Busqueda 37: tweet 172 almacenado
# Busqueda 37: tweet 173 almacenado
# Busqueda 37: tweet 174 almacenado
# Busqueda 37: tweet 175 almacenado
# Busqueda 37: tweet 176 almacenado
# Busqueda 37: tweet 177 almacenado
# Busqueda 37: tweet 178 almacenado
# Busqueda 37: tweet 179 almacenado
# Busqueda 37: tweet 180 almacenado
# Busqueda 37: tweet 181 almacenado
# Busqueda 37: tweet 182 almacenado
# Busqueda 37: tweet 183 almacenado
# Busqueda 37: tweet 184 almacenado
# Busqueda 37: tweet 185 almacenado
# Busqueda 37: tweet 186 almacenado
# Busqueda 37: tweet 187 almacenado
# Busqueda 37: tweet 188 almacenado
# Busqueda 37: tweet 189 almacenado
# Busqueda 37: tweet 190 almacenado
# Busqueda 37: tweet 191 almacenado
# Busqueda 37: tweet 192 almacenado
# Busqueda 37: tweet 193 almacenado
# Busqueda 37: tweet 194 almacenado
# Busqueda 37: tweet 195 almacenado
# Busqueda 37: tweet 196 almacenado
# Busqueda 37: tweet 197 almacenado
# Busqueda 37: tweet 198 almacenado
# Busqueda 37: tweet 199 almacenado
# Busqueda 37: tweet 200 almacenado
# Busqueda 37: tweet 201 almacenado
# Busqueda 37: tweet 202 almacenado
# Busqueda 37: tweet 203 almacenado
# Busqueda 37: tweet 204 almacenado
# Busqueda 37: tweet 205 almacenado
# Busqueda 37: tweet 206 almacenado
# Busqueda 37: tweet 207 almacenado
# Busqueda 37: tweet 208 almacenado
# Busqueda 37: tweet 209 almacenado
# Busqueda 37: tweet 210 almacenado
# Busqueda 37: tweet 211 almacenado
# Busqueda 37: tweet 212 almacenado
# Busqueda 37: tweet 213 almacenado
# Busqueda 37: tweet 214 almacenado
# Busqueda 37: tweet 215 almacenado
# Busqueda 37: tweet 216 almacenado
# Busqueda 37: tweet 217 almacenado
# Busqueda 37: tweet 218 almacenado
# Busqueda 37: tweet 219 almacenado
# Busqueda 37: tweet 220 almacenado
# Busqueda 37: tweet 221 almacenado
# Busqueda 37: tweet 222 almacenado
# Busqueda 37: tweet 223 almacenado
# Busqueda 37: tweet 224 almacenado
# Busqueda 37: tweet 225 almacenado
# Busqueda 37: tweet 226 almacenado
# Busqueda 37: tweet 227 almacenado
# Busqueda 37: tweet 228 almacenado
# Busqueda 37: tweet 229 almacenado
# Busqueda 37: tweet 230 almacenado
# Busqueda 37: tweet 231 almacenado
# Busqueda 37: tweet 232 almacenado
# Busqueda 37: tweet 233 almacenado
# Busqueda 37: tweet 234 almacenado
# Busqueda 37: tweet 235 almacenado
# Busqueda 37: tweet 236 almacenado
# Busqueda 37: tweet 237 almacenado
# Busqueda 37: tweet 238 almacenado
# Busqueda 37: tweet 239 almacenado
# Busqueda 37: tweet 240 almacenado
# Busqueda 37: tweet 241 almacenado
# Busqueda 37: tweet 242 almacenado
# Busqueda 37: tweet 243 almacenado
# Busqueda 37: tweet 244 almacenado
# Busqueda 37: tweet 245 almacenado
# Busqueda 37: tweet 246 almacenado
# Busqueda 37: tweet 247 almacenado
# Busqueda 37: tweet 248 almacenado
# Busqueda 37: tweet 249 almacenado
# Busqueda 37: tweet 250 almacenado
# Busqueda 37: tweet 251 almacenado
# Busqueda 37: tweet 252 almacenado
# Busqueda 37: tweet 253 almacenado
# Busqueda 37: tweet 254 almacenado
# Busqueda 37: tweet 255 almacenado
# Busqueda 37: tweet 256 almacenado
# Busqueda 37: tweet 257 almacenado
# Busqueda 37: tweet 258 almacenado
# Busqueda 37: tweet 259 almacenado
# Busqueda 37: tweet 260 almacenado
# Busqueda 37: tweet 261 almacenado
# Busqueda 37: tweet 262 almacenado
# Busqueda 37: tweet 263 almacenado
# Busqueda 37: tweet 264 almacenado
# Busqueda 37: tweet 265 almacenado
# Busqueda 37: tweet 266 almacenado
# Busqueda 37: tweet 267 almacenado
# Busqueda 37: tweet 268 almacenado
# Busqueda 37: tweet 269 almacenado
# Busqueda 37: tweet 270 almacenado
# Busqueda 37: tweet 271 almacenado
# Busqueda 37: tweet 272 almacenado
# Busqueda 37: tweet 273 almacenado
# Busqueda 37: tweet 274 almacenado
# Busqueda 37: tweet 275 almacenado
# Busqueda 37: tweet 276 almacenado
# Busqueda 37: tweet 277 almacenado
# Busqueda 37: tweet 278 almacenado
# Busqueda 37: tweet 279 almacenado
# Busqueda 37: tweet 280 almacenado
# Busqueda 37: tweet 281 almacenado
# Busqueda 37: tweet 282 almacenado
# Busqueda 37: tweet 283 almacenado
# Busqueda 37: tweet 284 almacenado
# Busqueda 37: tweet 285 almacenado
# Busqueda 37: tweet 286 almacenado
# Busqueda 37: tweet 287 almacenado
# Busqueda 37: tweet 288 almacenado
# Busqueda 37: tweet 289 almacenado
# Busqueda 37: tweet 290 almacenado
# Busqueda 37: tweet 291 almacenado
# Busqueda 37: tweet 292 almacenado
# Busqueda 37: tweet 293 almacenado
# Busqueda 37: tweet 294 almacenado
# Busqueda 37: tweet 295 almacenado
# Busqueda 37: tweet 296 almacenado
# Busqueda 37: tweet 297 almacenado
# Busqueda 37: tweet 298 almacenado
# Busqueda 37: tweet 299 almacenado
# Busqueda 37: tweet 300 almacenado
# Busqueda 37: tweet 301 almacenado
# Busqueda 37: tweet 302 almacenado
# Busqueda 37: tweet 303 almacenado
# Busqueda 37: tweet 304 almacenado
# Busqueda 37: tweet 305 almacenado
# Busqueda 37: tweet 306 almacenado
# Busqueda 37: tweet 307 almacenado
# Busqueda 37: tweet 308 almacenado
# Busqueda 37: tweet 309 almacenado
# Busqueda 37: tweet 310 almacenado
# Busqueda 37: tweet 311 almacenado
# Busqueda 37: tweet 312 almacenado
# Busqueda 37: tweet 313 almacenado
# Busqueda 37: tweet 314 almacenado
# Busqueda 37: tweet 315 almacenado
# Busqueda 37: tweet 316 almacenado
# Busqueda 37: tweet 317 almacenado
# Busqueda 37: tweet 318 almacenado
# Busqueda 37: tweet 319 almacenado
# Busqueda 37: tweet 320 almacenado
# Busqueda 37: tweet 321 almacenado
# Busqueda 37: tweet 322 almacenado
# Busqueda 37: tweet 323 almacenado
# Busqueda 37: tweet 324 almacenado
# Busqueda 37: tweet 325 almacenado
# Busqueda 37: tweet 326 almacenado
# Busqueda 37: tweet 327 almacenado
# Busqueda 37: tweet 328 almacenado
# Busqueda 37: tweet 329 almacenado
# Busqueda 37: tweet 330 almacenado
# Busqueda 37: tweet 331 almacenado
# Busqueda 37: tweet 332 almacenado
# Busqueda 37: tweet 333 almacenado
# Busqueda 37: tweet 334 almacenado
# Busqueda 37: tweet 335 almacenado
# Busqueda 37: tweet 336 almacenado
# Busqueda 37: tweet 337 almacenado
# Busqueda 37: tweet 338 almacenado
# Busqueda 37: tweet 339 almacenado
# Busqueda 37: tweet 340 almacenado
# Busqueda 37: tweet 341 almacenado
# Busqueda 37: tweet 342 almacenado
# Busqueda 37: tweet 343 almacenado
# Busqueda 37: tweet 344 almacenado
# Busqueda 37: tweet 345 almacenado
# Busqueda 37: tweet 346 almacenado
# Busqueda 37: tweet 347 almacenado
# Busqueda 37: tweet 348 almacenado
# Busqueda 37: tweet 349 almacenado
# Busqueda 37: tweet 350 almacenado
# Busqueda 37: tweet 351 almacenado
# Busqueda 37: tweet 352 almacenado
# Busqueda 37: tweet 353 almacenado
# Busqueda 37: tweet 354 almacenado
# Busqueda 37: tweet 355 almacenado
# Busqueda 37: tweet 356 almacenado
# Busqueda 37: tweet 357 almacenado
# Busqueda 37: tweet 358 almacenado
# Busqueda 37: tweet 359 almacenado
# Busqueda 37: tweet 360 almacenado
# Busqueda 37: tweet 361 almacenado
# Busqueda 37: tweet 362 almacenado
# Busqueda 37: tweet 363 almacenado
# Busqueda 37: tweet 364 almacenado
# Busqueda 37: tweet 365 almacenado
# Busqueda 37: tweet 366 almacenado
# Busqueda 37: tweet 367 almacenado
# Busqueda 37: tweet 368 almacenado
# Busqueda 37: tweet 369 almacenado
# Busqueda 37: tweet 370 almacenado
# Busqueda 37: tweet 371 almacenado
# Busqueda 37: tweet 372 almacenado
# Busqueda 37: tweet 373 almacenado
# Busqueda 37: tweet 374 almacenado
# Busqueda 37: tweet 375 almacenado
# Busqueda 37: tweet 376 almacenado
# Busqueda 37: tweet 377 almacenado
# Busqueda 37: tweet 378 almacenado
# Busqueda 37: tweet 379 almacenado
# Busqueda 37: tweet 380 almacenado
# Busqueda 37: tweet 381 almacenado
# Busqueda 37: tweet 382 almacenado
# Busqueda 37: tweet 383 almacenado
# Busqueda 37: tweet 384 almacenado
# Busqueda 37: tweet 385 almacenado
# Busqueda 37: tweet 386 almacenado
# Busqueda 37: tweet 387 almacenado
# Busqueda 37: tweet 388 almacenado
# Busqueda 37: tweet 389 almacenado
# Busqueda 37: tweet 390 almacenado
# Busqueda 37: tweet 391 almacenado
# Busqueda 37: tweet 392 almacenado
# Busqueda 37: tweet 393 almacenado
# Busqueda 37: tweet 394 almacenado
# Busqueda 37: tweet 395 almacenado
# Busqueda 37: tweet 396 almacenado
# Busqueda 37: tweet 397 almacenado
# Busqueda 37: tweet 398 almacenado
# Busqueda 37: tweet 399 almacenado
# Busqueda 37: tweet 400 almacenado
# Busqueda 37: tweet 401 almacenado
# Busqueda 37: tweet 402 almacenado
# Busqueda 37: tweet 403 almacenado
# Busqueda 37: tweet 404 almacenado
# Busqueda 37: tweet 405 almacenado
# Busqueda 37: tweet 406 almacenado
# Busqueda 37: tweet 407 almacenado
# Busqueda 37: tweet 408 almacenado
# Busqueda 37: tweet 409 almacenado
# Busqueda 37: tweet 410 almacenado
# Busqueda 37: tweet 411 almacenado
# Busqueda 37: tweet 412 almacenado
# Busqueda 37: tweet 413 almacenado
# Busqueda 37: tweet 414 almacenado
# Busqueda 37: tweet 415 almacenado
# Busqueda 37: tweet 416 almacenado
# Busqueda 37: tweet 417 almacenado
# Busqueda 37: tweet 418 almacenado
# Busqueda 37: tweet 419 almacenado
# Busqueda 37: tweet 420 almacenado
#                     id            user                     location  \
# 0  1252051927136735232       antoniogm             Orcas Island, WA
# 1  1252051929947164677   alexyamustdie                       Italia
# 2  1252051930001506306  RamuelLJackson  At this private location...
# 3  1252051929527513088    BrigadaMarin                         None
# 4  1252051930186231809          NTylai                    the south
#
#                                                tweet lang
# 0  @mannytabloid True. But is it about 'want' or ...   en
# 1  @joshuadun I probably lived all my life in qua...   en
# 2  MJ with a glass of yac and a cigar telling the...   en
# 3  Otra vez tienen que salir a explicar las expli...   es
# 4             crack, heroin, meth, ANYTHING but me !   en
# Busqueda 37 finalizada
#
# Busqueda 38: tweet 1 almacenado
# Busqueda 38: tweet 2 almacenado
# Busqueda 38: tweet 3 almacenado
# Busqueda 38: tweet 4 almacenado
# Busqueda 38: tweet 5 almacenado
# Busqueda 38: tweet 6 almacenado
# Busqueda 38: tweet 7 almacenado
# Busqueda 38: tweet 8 almacenado
# Busqueda 38: tweet 9 almacenado
# Busqueda 38: tweet 10 almacenado
# Busqueda 38: tweet 11 almacenado
# Busqueda 38: tweet 12 almacenado
# Busqueda 38: tweet 13 almacenado
# Busqueda 38: tweet 14 almacenado
# Busqueda 38: tweet 15 almacenado
# Busqueda 38: tweet 16 almacenado
# Busqueda 38: tweet 17 almacenado
# Busqueda 38: tweet 18 almacenado
# Busqueda 38: tweet 19 almacenado
# Busqueda 38: tweet 20 almacenado
# Busqueda 38: tweet 21 almacenado
# Busqueda 38: tweet 22 almacenado
# Busqueda 38: tweet 23 almacenado
# Busqueda 38: tweet 24 almacenado
# Busqueda 38: tweet 25 almacenado
# Busqueda 38: tweet 26 almacenado
# Busqueda 38: tweet 27 almacenado
# Busqueda 38: tweet 28 almacenado
# Busqueda 38: tweet 29 almacenado
# Busqueda 38: tweet 30 almacenado
# Busqueda 38: tweet 31 almacenado
# Busqueda 38: tweet 32 almacenado
# Busqueda 38: tweet 33 almacenado
# Busqueda 38: tweet 34 almacenado
# Busqueda 38: tweet 35 almacenado
# Busqueda 38: tweet 36 almacenado
# Busqueda 38: tweet 37 almacenado
# Busqueda 38: tweet 38 almacenado
# Busqueda 38: tweet 39 almacenado
# Busqueda 38: tweet 40 almacenado
# Busqueda 38: tweet 41 almacenado
# Busqueda 38: tweet 42 almacenado
# Busqueda 38: tweet 43 almacenado
# Busqueda 38: tweet 44 almacenado
# Busqueda 38: tweet 45 almacenado
# Busqueda 38: tweet 46 almacenado
# Busqueda 38: tweet 47 almacenado
# Busqueda 38: tweet 48 almacenado
# Busqueda 38: tweet 49 almacenado
# Busqueda 38: tweet 50 almacenado
# Busqueda 38: tweet 51 almacenado
# Busqueda 38: tweet 52 almacenado
# Busqueda 38: tweet 53 almacenado
# Busqueda 38: tweet 54 almacenado
# Busqueda 38: tweet 55 almacenado
# Busqueda 38: tweet 56 almacenado
# Busqueda 38: tweet 57 almacenado
# Busqueda 38: tweet 58 almacenado
# Busqueda 38: tweet 59 almacenado
# Busqueda 38: tweet 60 almacenado
# Busqueda 38: tweet 61 almacenado
# Busqueda 38: tweet 62 almacenado
# Busqueda 38: tweet 63 almacenado
# Busqueda 38: tweet 64 almacenado
# Busqueda 38: tweet 65 almacenado
# Busqueda 38: tweet 66 almacenado
# Busqueda 38: tweet 67 almacenado
# Busqueda 38: tweet 68 almacenado
# Busqueda 38: tweet 69 almacenado
# Busqueda 38: tweet 70 almacenado
# Busqueda 38: tweet 71 almacenado
# Busqueda 38: tweet 72 almacenado
# Busqueda 38: tweet 73 almacenado
# Busqueda 38: tweet 74 almacenado
# Busqueda 38: tweet 75 almacenado
# Busqueda 38: tweet 76 almacenado
# Busqueda 38: tweet 77 almacenado
# Busqueda 38: tweet 78 almacenado
# Busqueda 38: tweet 79 almacenado
# Busqueda 38: tweet 80 almacenado
# Busqueda 38: tweet 81 almacenado
# Busqueda 38: tweet 82 almacenado
# Busqueda 38: tweet 83 almacenado
# Busqueda 38: tweet 84 almacenado
# Busqueda 38: tweet 85 almacenado
# Busqueda 38: tweet 86 almacenado
# Busqueda 38: tweet 87 almacenado
# Busqueda 38: tweet 88 almacenado
# Busqueda 38: tweet 89 almacenado
# Busqueda 38: tweet 90 almacenado
# Busqueda 38: tweet 91 almacenado
# Busqueda 38: tweet 92 almacenado
# Busqueda 38: tweet 93 almacenado
# Busqueda 38: tweet 94 almacenado
# Busqueda 38: tweet 95 almacenado
# Busqueda 38: tweet 96 almacenado
# Busqueda 38: tweet 97 almacenado
# Busqueda 38: tweet 98 almacenado
# Busqueda 38: tweet 99 almacenado
# Busqueda 38: tweet 100 almacenado
# Busqueda 38: tweet 101 almacenado
# Busqueda 38: tweet 102 almacenado
# Busqueda 38: tweet 103 almacenado
# Busqueda 38: tweet 104 almacenado
# Busqueda 38: tweet 105 almacenado
# Busqueda 38: tweet 106 almacenado
# Busqueda 38: tweet 107 almacenado
# Busqueda 38: tweet 108 almacenado
# Busqueda 38: tweet 109 almacenado
# Busqueda 38: tweet 110 almacenado
# Busqueda 38: tweet 111 almacenado
# Busqueda 38: tweet 112 almacenado
# Busqueda 38: tweet 113 almacenado
# Busqueda 38: tweet 114 almacenado
# Busqueda 38: tweet 115 almacenado
# Busqueda 38: tweet 116 almacenado
# Busqueda 38: tweet 117 almacenado
# Busqueda 38: tweet 118 almacenado
# Busqueda 38: tweet 119 almacenado
# Busqueda 38: tweet 120 almacenado
# Busqueda 38: tweet 121 almacenado
# Busqueda 38: tweet 122 almacenado
# Busqueda 38: tweet 123 almacenado
# Busqueda 38: tweet 124 almacenado
# Busqueda 38: tweet 125 almacenado
# Busqueda 38: tweet 126 almacenado
# Busqueda 38: tweet 127 almacenado
# Busqueda 38: tweet 128 almacenado
# Busqueda 38: tweet 129 almacenado
# Busqueda 38: tweet 130 almacenado
# Busqueda 38: tweet 131 almacenado
# Busqueda 38: tweet 132 almacenado
# Busqueda 38: tweet 133 almacenado
# Busqueda 38: tweet 134 almacenado
# Busqueda 38: tweet 135 almacenado
# Busqueda 38: tweet 136 almacenado
# Busqueda 38: tweet 137 almacenado
# Busqueda 38: tweet 138 almacenado
# Busqueda 38: tweet 139 almacenado
# Busqueda 38: tweet 140 almacenado
# Busqueda 38: tweet 141 almacenado
# Busqueda 38: tweet 142 almacenado
# Busqueda 38: tweet 143 almacenado
# Busqueda 38: tweet 144 almacenado
# Busqueda 38: tweet 145 almacenado
# Busqueda 38: tweet 146 almacenado
# Busqueda 38: tweet 147 almacenado
# Busqueda 38: tweet 148 almacenado
# Busqueda 38: tweet 149 almacenado
# Busqueda 38: tweet 150 almacenado
# Busqueda 38: tweet 151 almacenado
# Busqueda 38: tweet 152 almacenado
# Busqueda 38: tweet 153 almacenado
# Busqueda 38: tweet 154 almacenado
# Busqueda 38: tweet 155 almacenado
# Busqueda 38: tweet 156 almacenado
# Busqueda 38: tweet 157 almacenado
# Busqueda 38: tweet 158 almacenado
# Busqueda 38: tweet 159 almacenado
# Busqueda 38: tweet 160 almacenado
# Busqueda 38: tweet 161 almacenado
# Busqueda 38: tweet 162 almacenado
# Busqueda 38: tweet 163 almacenado
# Busqueda 38: tweet 164 almacenado
# Busqueda 38: tweet 165 almacenado
# Busqueda 38: tweet 166 almacenado
# Busqueda 38: tweet 167 almacenado
# Busqueda 38: tweet 168 almacenado
# Busqueda 38: tweet 169 almacenado
# Busqueda 38: tweet 170 almacenado
# Busqueda 38: tweet 171 almacenado
# Busqueda 38: tweet 172 almacenado
# Busqueda 38: tweet 173 almacenado
# Busqueda 38: tweet 174 almacenado
# Busqueda 38: tweet 175 almacenado
# Busqueda 38: tweet 176 almacenado
# Busqueda 38: tweet 177 almacenado
# Busqueda 38: tweet 178 almacenado
# Busqueda 38: tweet 179 almacenado
# Busqueda 38: tweet 180 almacenado
# Busqueda 38: tweet 181 almacenado
# Busqueda 38: tweet 182 almacenado
# Busqueda 38: tweet 183 almacenado
# Busqueda 38: tweet 184 almacenado
# Busqueda 38: tweet 185 almacenado
# Busqueda 38: tweet 186 almacenado
# Busqueda 38: tweet 187 almacenado
# Busqueda 38: tweet 188 almacenado
# Busqueda 38: tweet 189 almacenado
# Busqueda 38: tweet 190 almacenado
# Busqueda 38: tweet 191 almacenado
# Busqueda 38: tweet 192 almacenado
# Busqueda 38: tweet 193 almacenado
# Busqueda 38: tweet 194 almacenado
# Busqueda 38: tweet 195 almacenado
# Busqueda 38: tweet 196 almacenado
# Busqueda 38: tweet 197 almacenado
# Busqueda 38: tweet 198 almacenado
# Busqueda 38: tweet 199 almacenado
# Busqueda 38: tweet 200 almacenado
# Busqueda 38: tweet 201 almacenado
# Busqueda 38: tweet 202 almacenado
# Busqueda 38: tweet 203 almacenado
# Busqueda 38: tweet 204 almacenado
# Busqueda 38: tweet 205 almacenado
# Busqueda 38: tweet 206 almacenado
# Busqueda 38: tweet 207 almacenado
# Busqueda 38: tweet 208 almacenado
# Busqueda 38: tweet 209 almacenado
# Busqueda 38: tweet 210 almacenado
# Busqueda 38: tweet 211 almacenado
# Busqueda 38: tweet 212 almacenado
# Busqueda 38: tweet 213 almacenado
# Busqueda 38: tweet 214 almacenado
# Busqueda 38: tweet 215 almacenado
# Busqueda 38: tweet 216 almacenado
# Busqueda 38: tweet 217 almacenado
# Busqueda 38: tweet 218 almacenado
# Busqueda 38: tweet 219 almacenado
# Busqueda 38: tweet 220 almacenado
# Busqueda 38: tweet 221 almacenado
# Busqueda 38: tweet 222 almacenado
# Busqueda 38: tweet 223 almacenado
# Busqueda 38: tweet 224 almacenado
# Busqueda 38: tweet 225 almacenado
# Busqueda 38: tweet 226 almacenado
# Busqueda 38: tweet 227 almacenado
# Busqueda 38: tweet 228 almacenado
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\response.py in _error_catcher(self)
#     424             try:
# --> 425                 yield
#     426
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\http\client.py in read(self, amt)
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\http\client.py in readinto(self, b)
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\http\client.py in _readinto_chunked(self, b)
#     590                 if len(mvb) <= chunk_left:
# --> 591                     n = self._safe_readinto(mvb)
#     592                     self.chunk_left = chunk_left - n
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\http\client.py in _safe_readinto(self, b)
#     635             else:
# --> 636                 n = self.fp.readinto(mvb)
#     637             if not n:
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\ssl.py in read(self, len, buffer)
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# <ipython-input-5-1d828c186946> in <module>
#       2     stream = Stream_Tweetslistener()
#       3     streaming_api = tweepy.Stream(auth=api.auth, listener=stream, tweet_mode='extended')
# ----> 4     streaming_api.filter(languages= sp.lenguajes, track= sp.track, locations= [-10.6,34.4,74.7,57.0,-125.2,25.0,-67.3,48.7], stall_warnings=True)
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# ~\AppData\Roaming\Python\Python37\site-packages\six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     527                         # raised during streaming, so all calls with incorrect
#     528                         # Content-Length are caught.
# --> 529                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     530
#     531         if data:
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\response.py in _error_catcher(self)
#     428                 # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     429                 # there is yet no clean way to get at it from this context.
# --> 430                 raise ReadTimeoutError(self._pool, None, "Read timed out.")
#     431
#     432             except BaseSSLError as e:
#
# ReadTimeoutError: HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
