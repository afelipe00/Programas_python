# %%
import pandas as pd

# %%
df_price = pd.read_csv("price_paid_records.csv")
df_price
# Out:
#                    Transaction unique identifier   Price  Date of Transfer  \
# 0         {81B82214-7FBC-4129-9F6B-4956B4A663AD}   25000  1995-08-18 00:00
# 1         {8046EC72-1466-42D6-A753-4956BF7CD8A2}   42500  1995-08-09 00:00
# 2         {278D581A-5BF3-4FCE-AF62-4956D87691E6}   45000  1995-06-30 00:00
# 3         {1D861C06-A416-4865-973C-4956DB12CD12}   43150  1995-11-24 00:00
# 4         {DD8645FD-A815-43A6-A7BA-4956E58F1874}   18899  1995-06-23 00:00
# ...                                          ...     ...               ...
# 22489343  {4C4EE000-291A-1854-E050-A8C063054F34}  175000  2017-02-20 00:00
# 22489344  {4C4EE000-291B-1854-E050-A8C063054F34}  586945  2017-02-15 00:00
# 22489345  {4C4EE000-291C-1854-E050-A8C063054F34}  274000  2017-02-24 00:00
# 22489346  {4C4EE000-291D-1854-E050-A8C063054F34}   36000  2017-02-22 00:00
# 22489347  {4C4EE000-291E-1854-E050-A8C063054F34}  145000  2017-03-03 00:00
#
# ...

# %%
#mapper 1
sr_date =  df_price['Date of Transfer']
lst_year = []
for date in sr_date:
    year = date.split('-')
    lst_year.append((year[0],1))
lst_year
# Out:
# [('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
#  ('1995', 1),
# ...

# %%
#ordenar
lst_year.sort()

# %%
#reducer
srs_years = pd.Series(lst_year)
srs_years.value_counts()
# Out:
# (2002, 1)    1351256
# (2006, 1)    1326161
# (2007, 1)    1272921
# (2004, 1)    1270409
# (2003, 1)    1257140
# (2001, 1)    1245112
# (1999, 1)    1194064
# (2000, 1)    1128742
# (1997, 1)    1093669
# (2005, 1)    1061686
# (1998, 1)    1049739
# (2016, 1)    1032558
# (2015, 1)    1007421
# (2014, 1)     982943
# (1996, 1)     964695
# (2013, 1)     810111
# (1995, 1)     796777
# (2012, 1)     668295
# (2010, 1)     663342
# (2011, 1)     661055
# (2008, 1)     650492
# (2009, 1)     625662
# (2017, 1)     375098
# dtype: int64

# %%
#Town/City
#price
df_prom = pd.DataFrame(df_price['Town/City'])
df_prom['Price'] = df_price['Price']
df_prom
# Out:
#              Town/City   Price
# 0               OLDHAM   25000
# 1                GRAYS   42500
# 2           HIGHBRIDGE   45000
# 3              BEDFORD   43150
# 4            WAKEFIELD   18899
# ...                ...     ...
# 22489343         LEEDS  175000
# 22489344      WETHERBY  586945
# 22489345  HUDDERSFIELD  274000
# 22489346       HALIFAX   36000
# 22489347         LEEDS  145000
#
# [22489348 rows x 2 columns]

# %%
lst_prom = []
for fill,row in df_prom.iterrows():
    lst_prom.append((row['Town/City'],row['Price']))
lst_prom
# Out:
#  67000),
#  ('BEVERLEY', 27000),
#  ('LEAMINGTON SPA', 100700),
#  ('NEWTON-LE-WILLOWS', 41000),
#  ('LONDON', 180000),
#  ('NORTHAMPTON', 63500),
#  ('WARRINGTON', 116750),
#  ('BURGESS HILL', 62800),
#  ('ALTON', 59500),
#  ('TELFORD', 69950),
#  ('BALDOCK', 35200),
#  ('DUNSTABLE', 31000),
#  ('NEWBURY', 142000),
#  ('CHARD', 26500),
#  ('WILMSLOW', 61500),
#  ('DIDCOT', 59999),
#  ('SOUTHAMPTON', 69950),
#  ('GRANTHAM', 23950),
#  ('NEWMARKET', 48500),
#  ('NORTHAMPTON', 43500),
#  ('MIDHURST', 48000),
#  ('BRIERLEY HILL', 64950),
#  ('UXBRIDGE', 124500),
#  ('BIRMINGHAM', 48950),
#  ('DOVER', 147000),
#  ('YEOVIL', 64000),
#  ('BURGESS HILL', 59000),
#  ('LEICESTER', 57000),
#  ('SHEFFIELD', 26500),
#  ('OXTED', 136000),
#  ('OXFORD', 62000),
#  ('PORTHCAWL', 52000),
#  ('HEREFORD', 77000),
#  ('SEVENOAKS', 88000),
#  ('CHELMSFORD', 58000),
#  ('COLCHESTER', 46000),
#  ('LONDON', 90000),
#  ('COLCHESTER', 30000),
#  ('WALLASEY', 81000),
#  ('BRISTOL', 46500),
# ...

# %%
srs_prom = pd.Series(lst_prom)
srs_prom.mean(axis=0)

# %%
#reducer3
dic_minimo = {}
for col,row in df_prom:
    if row['Town/City'] in dic_minimo:
        if dic_minimo[row['Town/City']] > row['Price']:
            dic_minimo[row['Town/City']] = row['Price']
    else:
        dic_minimo[row['Town/City']] = row['Price']
dic_minimo

# %%
#mapper4
df_2015 = df_price[df_price['Twon/City'] == 'STAMFORD']
df_2015.drop(df_2015[df_2015['Year'] != 2015].index)
df_2015 = pd.DataFrame(df_2015['Town/City','Price'])
df_2015

# %%
#reducer4
df_2015 = df_2015.sort_values('Price')

# %%
#mapper
