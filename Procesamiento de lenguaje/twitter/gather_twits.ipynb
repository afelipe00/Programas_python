# %%
import tweepy
from random import randint
import json
import time
import csv
import pandas as pd
import os

# %%
#funciones de busqueda y recoleccion
limit_search = 20
cont_iter = 0
size_search = 420
list_search = []
def pickup_tweets_buffer(tweet):
    global size_search
    global cont_iter
    global limit_search
    if not 'RT @' in tweet.text:    
        list_search.append(tweet)
        print(f'tweet {len(list_search)} almacenado...')
        if size_search == len(list_search):
            pickup_df(df_search)
            cont_iter+=1
            if cont_iter < limit_search:
                list_search.clear()
                print(f'Busqueda {cont_iter} finalizada\n ')
            else:
                print(f'\nPROCESO DE BUSQUEDA DE TWEET FINALIZADO CON EXITO\n')

def pickup_df(df_tweets):
    ls_dict = list()
    for t in df_tweets:
        dic_tweet = {
        'id': t.id,
        'user': t.user.screen_name,
        'location': t.user.location,
        'tweet': t.text,
        'lang' : t.lang
        }
        ls_dict.append(dic_tweet)
    df_final = pd.DataFrame(ls_dict)
    print(df_final.head(5))
    csv_file(df_final)
def csv_file(df_final):
    df_final.to_csv('tweet.csv',mode= 'a',index= False)

# %%
class Search_property():
    consumer_key = "x66CyvlFTVxRySc9QG9gXhXbw"
    consumer_secret = "PwPWqXYWHtJocPmprTLwYzdS0BMBLmMKU9DNYUVWvheKI0m7r0"
    access_token = "320544075-GwBCdhpxzInw9wLxVMkIbOEq4FNoGqhfR8Vq0qPl"
    access_token_secret = "5SDDJksgt4TZxb46ybERnGCvgPyXODXgGp4JEaiB5WtGd"

    def __init__(self):
        self.america = [-125.2,25.0,-67.3,48.7]
        self.europa = [-10.6,34.4,74.7,57.0]    
        self.lenguajes = ['en', 'es']
        self.track = ['Coronavirus', 'coronavirus', 'covid-19', 'COVID-19', "SARS-CoV-2", "covid 19", "quarantine", "pandemia", "cuarentena", "COVID19", "covid19"]
        self.c_key = self.consumer_key
        self.c_secret = self.consumer_secret
        self.a_token = self.access_token
        self.a_secret = self.access_token_secret

class Stream_Tweetslistener(tweepy.StreamListener):
    #se incia la coneccion
    def on_connect(self):
        print("Coneccion iniciada")
        return super().on_connect()
    #aca es donde se debe realizar la recoleccion de los datos
    def on_status(self, status):
        tweet = status
        pickup_tweets_buffer(tweet)
        global cont_iter
        global limit_search
        if cont_iter == limit_search:
            print('desconectando...')
            stream.on_disconnect(1)
    def on_error(self, status_code):
        print('Error: ', status_code)

# %%
sp = Search_property()
auth = tweepy.OAuthHandler(sp.c_key,sp.c_secret)
auth.set_access_token(sp.a_token,sp.a_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
if __name__ == "__main__": 
    stream = Stream_Tweetslistener()
    streaming_api = tweepy.Stream(auth=api.auth, listener=stream, text_mode='extended')
    streaming_api.filter(languages= sp.lenguajes, track= sp.track, locations= sp.america, stall_warnings=True)
# Out:
# do...
# desconectando...
# desconectando...
# tweet 1435 almacenado...
# desconectando...
# desconectando...
# tweet 1436 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1437 almacenado...
# desconectando...
# desconectando...
# tweet 1438 almacenado...
# desconectando...
# desconectando...
# desconectando...
# tweet 1439 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1440 almacenado...
# desconectando...
# tweet 1441 almacenado...
# desconectando...
# desconectando...
# desconectando...
# tweet 1442 almacenado...
# desconectando...
# desconectando...
# tweet 1443 almacenado...
# desconectando...
# tweet 1444 almacenado...
# desconectando...
# desconectando...
# desconectando...
# tweet 1445 almacenado...
# desconectando...
# desconectando...
# tweet 1446 almacenado...
# desconectando...
# tweet 1447 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 
almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1665 almacenado...
# desconectando...
# tweet 1666 almacenado...
# desconectando...
# tweet 1667 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1668 almacenado...
# desconectando...
# tweet 1669 almacenado...
# desconectando...
# desconectando...
# desconectando...
# tweet 1670 almacenado...
# desconectando...
# desconectando...
# desconectando...
# tweet 1671 almacenado...
# desconectando...
# desconectando...
# desconectando...
# tweet 1672 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1673 almacenado...
# desconectando...
# tweet 1674 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1675 almacenado...
# desconectando...
# tweet 1676 almacenado...
# desconectando...
# tweet 1677 almacenado...
# desconectando...
# desconectando...
# desconectando...
# tweet 1678 almacenado...
# desconectando...
# tweet 1679 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1680 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1681 almacenado...
# desconectando...
# desconectando...
# desconectando...
# tweet 1682 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1683 almacenado...
# desconectando...
# tweet 1684 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1685 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1686 almacenado...
# desconectando...
# tweet 1687 almacenado...
# desconectando...
# desconectando...
# tweet 1688 almacenado...
# desconectando...
# tweet 1689 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1690 almacenado...
# desconectando...
# desconectando...
# desconectando...
# tweet 1691 almacenado...
# desconectando...
# desconectando...
# tweet 1692 almacenado...
# desconectando...
# desconectando...
# tweet 1693 almacenado...
# desconectando...
# tweet 1694 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1695 almacenado...
# desconectando...
# desconectando...
# tweet 1696 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1697 almacenado...
# desconectando...
# tweet 1698 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1699 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1700 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1701 almacenado...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# desconectando...
# tweet 1702 almacenado...
# desconectando...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-45331ecb6342> in <module>
#       2     stream = Stream_Tweetslistener()
#       3     streaming_api = tweepy.Stream(auth=api.auth, listener=stream, text_mode='extended')
# ----> 4     streaming_api.filter(languages= sp.lenguajes, track= sp.track, locations= sp.america, stall_warnings=True)
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\http\client.py in _readinto_chunked(self, b)
#     589
#     590                 if len(mvb) <= chunk_left:
# --> 591                     n = self._safe_readinto(mvb)
#     592                     self.chunk_left = chunk_left - n
#     593                     return total_bytes + n
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\http\client.py in _safe_readinto(self, b)
#     634                 n = self.fp.readinto(temp_mvb)
#     635             else:
# --> 636                 n = self.fp.readinto(mvb)
#     637             if not n:
#     638                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
